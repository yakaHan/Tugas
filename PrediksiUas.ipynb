# %% [markdown]
# <a href="https://colab.research.google.com/github/yakaHan/Tugas/blob/main/PrediksiUas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df5022 = pd.read_excel('/content/drive/MyDrive/dataset2.xlsx')

# %%
df5022
# Out:
#       Unnamed: 0                 artists  popularity(y)  duration_ms(x)  \
# 0            0.0             Gen Hoshino             73          230666
# 1            1.0            Ben Woodward             55          149610
# 2            2.0  Ingrid Michaelson;ZAYN             57          210826
# 3            3.0            Kina Grannis             71          201933
# 4            4.0        Chord Overstreet             82          198853
# ...          ...                     ...            ...             ...
# 997        997.0              Pigeon Pit             26          186461
# 998        998.0             Chuck Ragan             26          217293
# 999        999.0            Frank Turner             25          297093
# 1000      1000.0  Limoblaze;Lecrae;Happi             64          168000
# 1001         NaN                     NaN          42547       215064957
#
#              x.y              x2       y2  Unnamed: 7
# 0       16838618     53206803556     5329         NaN
# 1        8228550     22383152100     3025         NaN
# 2       12017082     44447602276     3249         NaN
# 3       14337243     40776936489     5041         NaN
# 4       16305946     39542515609     6724         NaN
# ...          ...             ...      ...         ...
# 997      4847986     34767704521      676         NaN
# 998      5649618     47216247849      676         NaN
# 999      7427325     88264250649      625         NaN
# 1000    10752000     28224000000     4096         NaN
# 1001  9146658850  49298892371123  2082233    0.005903
#
# [1002 rows x 8 columns]

# %%
x = df5022['duration_ms(x)']
y = df5022['popularity(y)']

# %%
regr = linear_model.LinearRegression()
regr.fit(x.values.reshape(-1,1), y)

print('Nilai a (intercept) =', regr.intercept_)
print('Nilai b (coefficients) =', regr.coef_)
# Out:
# Nilai a (intercept) = 0.005643569298058537
# Nilai b (coefficients) = [0.00019782]

# %%
new_iklan = 5000
print('Hasil prediksi penjualan dengan nilai iklan 500 = \n', regr.predict([[new_iklan]]))
# Out:
# Hasil prediksi penjualan dengan nilai iklan 500 =
#  [0.9947441]

# %%
import matplotlib.pyplot as plt

plt.xlabel('DURASI')
plt.ylabel('POPULARITAS')
plt.scatter(x,y, color='blue')
plt.plot(x, regr.predict(x.values.reshape(-1,1)), color='red')
